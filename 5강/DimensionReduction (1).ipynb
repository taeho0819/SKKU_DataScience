# %% [markdown]
# ## t-SNE Dimension Reduction
# * t-SNE는 비선형 차원 축소 기법으로, 고차원 데이터를 특히 2, 3차원 등으로 줄여 가시화하는데에 유용하게 사용

# %%
from sklearn.datasets import load_digits
import matplotlib
import matplotlib.pyplot as plt

# data load
digits = load_digits()

# subplot 객체 생성
fig, axes = plt.subplots(2, 5, #  subplot객체(2x5)를 axes에 할당
                         subplot_kw={'xticks':(), 'yticks':()}) # subplot 축 눈금 해제

for ax, img in zip(axes.ravel(), digits.images): # axes.ravel()과 digits.images를 하나씩 할당
    ax.imshow(img)

plt.gray() # 그래프 흑백
plt.show() # 그래프 출력

# %%
from sklearn.decomposition import PCA

# PCA 모델을 생성

 # n_components= 주성분 갯수

 # PCA 적용
# Out:
# PCA(n_components=2)

# %%
# 처음 두 개의 주성분으로 숫자 데이터를 변환
 # PCA를 데이터에 적용

# PCA를 데이터에 적용
colors = ['#476A2A', '#7851B8', '#BD3430', '#4A2D4E', '#875525',
               '#A83683', '#4E655E', '#853541', '#3A3120', '#535D8E']


for i in range(len(digits.data)): # digits.data의 길이까지 정수 갯수
    # 숫자 텍스트를 이용해 산점도 그리기
    plt.text(# code here
             color=colors[digits.target[i]], # 산점도 색상
             fontdict={'weight':'bold', 'size':9}) # font 설정

# lim 설정
# code here

plt.xlabel('first principle component') # x 축 이름
plt.ylabel('second principle componet') # y 축 이름
plt.show()

# %%
### TSNE모델에는 transform 메소드가 없고 fit_transform만 있음



# library import
from sklearn.manifold import TSNE

# t-SNE 모델 생성 및 학습
# Out:
# /Users/gojunseo/Library/Python/3.8/lib/python/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/gojunseo/Library/Python/3.8/lib/python/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
# 시각화
for i in range(len(digits.data)): # 0부터  digits.data까지 정수
    plt.text(# code here
             color=colors[digits.target[i]], # 색상
             fontdict={'weight': 'bold', 'size':9}) # font

# lim 설정
plt.xlabel('t-SNE Feature1') # x축 이름
plt.ylabel('t-SNE Feature2') # y축 이름
plt.show() # 그래프 출력

# %% [markdown]
# ## PCA Dimension Reduction

# %%
# To getter a better understanding of interaction of the dimensions
# plot the first three PCA dimensions
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA

iris = load_iris()
# PCA 불러와보기

# %%
fig = plt.figure(1, figsize=(8, 6))
ax = Axes3D(fig, elev=-150, azim=110)
# 산점도 플랏 그리기


ax.set_title("First three PCA directions")
ax.set_xlabel("1st eigenvector")
ax.w_xaxis.set_ticklabels([])
ax.set_ylabel("2nd eigenvector")
ax.w_yaxis.set_ticklabels([])
ax.set_zlabel("3rd eigenvector")
ax.w_zaxis.set_ticklabels([])
plt.show
# Out:
# /var/folders/ls/c3p0f5dn5_37r7vg64ljb0240000gn/T/ipykernel_50634/808683247.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig, elev=-150, azim=110)
# <function matplotlib.pyplot.show(close=None, block=None)>
