# %% [markdown]
# ## Load Dataset & Analysis (iris)

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

iris_data = load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris_data.data, iris_data.target, test_size=0.2, random_state=11)

# %% [markdown]
# ## Import Decision Tree Classifier
# docs: https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html

# %%
from sklearn.tree import DecisionTreeClassifier
# Load Decision Tree Classifier and train/predict
# Code Here!

# %%
from sklearn.metrics import classification_report

# Generate Classification Report from y_test, y_pred
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       0.83      1.00      0.91        10
#            2       1.00      0.82      0.90        11
#
#     accuracy                           0.93        30
#    macro avg       0.94      0.94      0.94        30
# weighted avg       0.94      0.93      0.93        30

# %% [markdown]
# ## Visualize Tree

# %%
import matplotlib.pyplot as plt
from sklearn import tree

# Visualize Decision Tree
# Code Here!

# %% [markdown]
# ## Visualize Feature Importance

# %%
import seaborn as sns
import numpy as np

# feature importance 추출
print("Feature Importances:\n{0}\n".format(np.round(dt_clf.feature_importances_, 3)))

# feature 별 feature importance 매핑
# Code Here!

# feature importance 시각화
# Code Here!
# Out:
# Feature Importances:
# [0.025 0.    0.555 0.42 ]
#
# sepal length (cm): 0.025
# sepal width (cm): 0.000
# petal length (cm): 0.555
# petal width (cm): 0.420

# %% [markdown]
# ## Visualize Classification Result

# %%
import matplotlib.pyplot as plt
from sklearn import datasets

# import some data to play with
iris = datasets.load_iris()
X = iris.data[:, 2:]  # we only take the first two features.
y = iris.target

# Visualize Feature Importance
## Min-Max Scaling

## Generate Figure using plt


## Set xlim, ylim

# %% [markdown]
# ## Difference Between max_depth
# * 여러 파라미터를 실험하기 위하여 파라미터를 변경하며 성능 실험 진행하기

# %%
accuracy_scores = []
from sklearn import tree
plt.figure(figsize=(32, 10)) 

from sklearn.metrics import accuracy_score
for i in range(1, 5):
    # Set Decision Tree Classifier
    
    
    # Set subplot and draw tree
    
    # Predict and accumulate accuracy score
    

# Compare result using Line Graph

# %% [markdown]
# ### Feature importance based on mean decrease in impurity
# 자료 출처: https://scikit-learn.org/stable/auto_examples/ensemble/plot_forest_importances.html

# %% [markdown]
# ### What is MDI (Mean Decrease in Impurity)
# * Gini Importance Score와 동일한 뜻으로, 전체적으로 Classification의 불순도를 얼마나 감소 시키는지를 의미한다.
# * 자세한 내용은 https://m.blog.naver.com/PostView.naver?isHttpsRedirect=true&blogId=sungmk86&logNo=221204932461 이곳을 통해서 확인해볼 수 있다.

# %%
# 분류기로부터 중요 피쳐 추출하고 std 계산하기
# np.std: standard deviation (표준편차)

# %%
import pandas as pd

# Set importance score using Pandas
forest_importances = pd.Series(importances, index=iris_data.feature_names)

# Draw Feature importances using MDI
fig, ax = plt.subplots()
# Code Here!

# %% [markdown]
# ## Ensemble Methods
# * [Scikit Learn Documentation for ensemble Method](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.ensemble)
#
# ### Tree Algorithms
# 1. [RandomForestClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html#sklearn.ensemble.RandomForestClassifier)
# 2. [AdaBoostClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.AdaBoostClassifier.html)

# %% [markdown]
# ## Random Forest Classifier
# > A random forest is a meta estimator that fits a number of decision tree classifiers on various sub-samples of the dataset and uses averaging to improve the predictive accuracy and control over-fitting.
#
# > 디시전 트리 여러개를 통해 데이터셋을 서브 샘플링하고 앙상블링 하는 기법 (앙상블: 여러개의 classifier를 조합하여 성능을 올리는 기법)
#
# * criterion = {“gini”, “entropy”}
# * max_depth = maximun depth
# * n_estimators: the number of trees in the forests

# %%
from sklearn.ensemble import RandomForestClassifier

# Set RandomForestClassifier
# Out:
# RandomForestClassifier(random_state=0)

# %%
from sklearn.ensemble import AdaBoostClassifier

# Set RandomForestClassifier
